# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('train.xlsx')

# %%
df.shape
# Out:
# (3998, 38)

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df.head()
# Out:
#            ID   Salary        DOJ                  DOL  \
# train  203097   420000 2012-06-01              present
# train  579905   500000 2013-09-01              present
# train  810601   325000 2014-06-01              present
# train  267447  1100000 2011-07-01              present
# train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                     Designation    JobCity Gender        DOB  10percentage  \
# train   senior quality engineer  Bangalore      f 1990-02-19          84.3
# train         assistant manager     Indore      m 1989-10-04          85.4
# train          systems engineer    Chennai      f 1992-08-03          85.0
# train  senior software engineer    Gurgaon      m 1989-12-05          85.6
# train                       get    Manesar      m 1991-02-27          78.0
#
#                               10board          ...            ComputerScience  \
# train  board ofsecondary education,ap          ...                         -1
# ...

# %%
df.tail()
# Out:
#            ID  Salary        DOJ                  DOL  \
# train   47916  280000 2011-10-01  2012-10-01 00:00:00
# train  752781  100000 2013-07-01  2013-07-01 00:00:00
# train  355888  320000 2013-07-01              present
# train  947111  200000 2014-07-01  2015-01-01 00:00:00
# train  324966  400000 2013-02-01              present
#
#                        Designation           JobCity Gender        DOB  \
# train            software engineer        New Delhi       m 1987-04-15
# train             technical writer         Hyderabad      f 1992-08-27
# train  associate software engineer         Bangalore      m 1991-07-03
# train           software developer  Asifabadbanglore      f 1992-03-20
# train      senior systems engineer           Chennai      f 1991-02-26
#
#        10percentage      10board          ...            ComputerScience  \
# train         52.09         cbse          ...                         -1
# ...

# %%
df_2 = pd.read_csv('SaratogaHouses.csv')

# %%
df_2.shape
# Out:
# (1728, 17)

# %%
df[df['Salary'] > 2000000]
# Out:
#             ID   Salary        DOJ                  DOL  \
# train   260866  2600000 2011-07-01  2013-04-01 00:00:00
# train   325412  3500000 2013-01-01  2014-10-01 00:00:00
# train    48107  4000000 2010-07-01  2015-03-01 00:00:00
# train   641560  2020000 2014-06-01  2015-04-01 00:00:00
# train   342930  2050000 2015-04-01              present
# train  1283923  3000000 2014-09-01  2015-03-01 00:00:00
# train   232481  2500000 2012-04-01              present
# train   281074  2300000 2014-03-01              present
# train    41147  4000000 2010-01-01  2011-12-01 00:00:00
#
#                      Designation         JobCity Gender        DOB  \
# train      application developer              -1      m 1989-05-27
# train  assistant system engineer            Pune      f 1990-08-07
# train   senior software engineer       New Delhi      m 1987-09-09
# train         operations analyst       Bangalore      m 1990-07-20
# ...

# %%
df_2.head()
# Out:
#    Unnamed: 0   price  lotSize  age  landValue  livingArea  pctCollege  \
# 0           1  132500     0.09   42      50000         906          35
# 1           2  181115     0.92    0      22300        1953          51
# 2           3  109000     0.19  133       7300        1944          51
# 3           4  155000     0.41   13      18700        1944          51
# 4           5   86060     0.11    0      15000         840          51
#
#    bedrooms  fireplaces  bathrooms  rooms          heating      fuel  \
# 0         2           1        1.0      5         electric  electric
# 1         3           0        2.5      6  hot water/steam       gas
# 2         4           1        1.0      8  hot water/steam       gas
# 3         3           1        1.5      5          hot air       gas
# 4         2           0        1.0      3          hot air       gas
#
#                sewer waterfront newConstruction centralAir
# 0             septic         No              No         No
# ...

# %%
df_2[df_2['bedrooms'] == 5][['price','bedrooms','livingArea','rooms']]
# Out:
#        price  bedrooms  livingArea  rooms
# 135   119900         5        1701     10
# 183   230000         5        1912     10
# 210   179900         5        2304      9
# 286   187900         5        2464      9
# 297   191500         5        2310     12
# 302   187500         5        2662      9
# 321   187900         5        2576      9
# 334   201000         5        3140     10
# 337   215900         5        2310      9
# 345   245000         5        2462      8
# 356   225000         5        2521     12
# 364   150000         5        1965     11
# 389   240000         5        2708     12
# 396   412500         5        3896     12
# 414   235000         5        2576     11
# 434   435000         5        4211     12
# 492   325000         5        2463     12
# 570   760000         5        3148     12
# 590   620000         5        4856     12
# 756   174000         5        2106     11
# 761   210000         5        2224     11
# ...

# %%
df_2.sort_values('price', ascending=False).head()[['price','bedrooms','rooms']]
# Out:
#        price  bedrooms  rooms
# 1201  775000         5     12
# 701   775000         3      9
# 570   760000         5     12
# 1206  725000         4     10
# 1278  670000         4      8

# %%
x = np.array([i for i in range(51)])

# %%
y = x ** 2

# %%
plt.plot(x,y,'ro')
plt.show()

# %%
df_2['heating'].value_counts()
# Out:
# hot air            1121
# electric            305
# hot water/steam     302
# Name: heating, dtype: int64

# %%
import seaborn as sns

# %%
matches = pd.read_csv('matches.csv')

# %%
matches.shape
# Out:
# (577, 18)

# %%
matches.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
sns.countplot(x=matches['season'], data=matches)
plt.show()

# %%
sns.countplot(x=matches['winner'], data=matches)
plt.xticks(rotation='vertical')
plt.show()

# %%
matches.drop_duplicates('season',keep='last')[['season','winner']]
# Out:
#      season                 winner
# 57     2008       Rajasthan Royals
# 114    2009        Deccan Chargers
# 174    2010    Chennai Super Kings
# 247    2011    Chennai Super Kings
# 321    2012  Kolkata Knight Riders
# 397    2013         Mumbai Indians
# 457    2014  Kolkata Knight Riders
# 516    2015         Mumbai Indians
# 576    2016    Sunrisers Hyderabad

# %%
matches['season'][0] = 2005
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
matches['season'][0]
# Out:
# 2005
